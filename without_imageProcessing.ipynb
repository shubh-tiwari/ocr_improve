# %%
from tesserocr import PyTessBaseAPI
from tesserocr import PSM

tess = "C:/Users/shubh/Anaconda3/pkgs/tesserocr-2.4.0-py37_tesseract_4.0.0_0/Lib/site-packages/tesserocr/tessdata"
with PyTessBaseAPI(path=tess, lang='eng', psm=PSM.SPARSE_TEXT_OSD) as api:
    api.SetImageFile('sampe4.png')
    print(api.GetUTF8Text())
# Out:
# TAX INVOICE
#
# oRamaL
#
# ST REGNo: N@comass
#
# 78 5103 2017 1051 s page 1ot
#
# R Jor ST
#
# -
#
# 1000208100005
#
# B8R s
#
# 1000216000501
#
# s80Ewo sTREET
#
# ToxinicaOwe
#
# 31032017 1051 h
#
# Pasen NRIGHRN
#
# siosorn
#
# SReone 8009
#
# Vetome
#
# 31032017001 s
#
# Vi1 Locsion
#
# ceurcoacoTo
#
# PATIENT R JOHN SUITH
#
# PaymentCios
#
# PRvATE
#
# camorest
#
# Tyt oy
#
# AMOURT (S5
#
# SERVICE CoDE.
#
# DESCRIPTION.
#
# auanTiry
#
# FoRste
#
# mount
#
# Payable
#
# Proressiona s -poc:
#
# AR CONS - REPEAT VST
#
# o100
#
# oo
#
# Subtot
#
# )
#
# e
#
# onucs 1PRESCRPTIONS IUECTIONS
#
# Pua0
#
# Bencay GreaseLess a2
#
# B
#
# 0
#
# Pz
#
# TRANADOLHCL NG CAP
#
# aco
#
# a0
#
# oo
#
# o
#
# Pz
#
# AENORONATE 50D T0WG, UT0 2801 48,
#
# Pz
#
# KETOPROFEN JUG PUASTER 65
#
# [
#
# e
#
# PrasTo
#
# PARACETAVOL SO0WG TAD
#
# w20
#
# 2
#
# §Zovsn
#
# om0
#
# Y
#
# PrasTo
#
# AL 45OMG AN O 700 U IS
#
# Subtot
#
# £
#
# s
#
# ToTAL CHARGES
#
# o
#
# wouNT PAvABLE
#
# AMOUNT PAYABLE BEFORE TAX
#
# o
#
# 00: 74 687
#
# 20
#
# e
#
# WOUNT PAABLE AFTER TAX
#
# NET AMOUNT PATASLE
#
# s
#
# 307
#
# MR JON ST
#
# Pavment
#
# ers
#
# [——
#
# oz Avex
#
# ars
#
# AWONT DUE FROW
#
# MR Lo SHITH
#
# om0
#
# A
#
# Vou s sevediy MARY TAN DENO ONLY
#
# =

# %%
with PyTessBaseAPI(path=tess, lang='eng', psm=PSM.SPARSE_TEXT_OSD) as api:
    api.SetImageFile('sam.jpg')
    print(api.GetUTF8Text())
# Out:
# tan chay yee
#
# *%x COPY **+
#
# 0)C MARKETING SDN BHD
#
# ROC NO: 538358-H
#
# NO 2 & 4, JALAN BAYU 4,
#
# BANDAR SERT ALAM,
#
# B1750 MASAL, JOHOR
#
# Tel:07-388 2218 Fax:07-386 8218
#
# Emaif: np@ojcgroup.cam
#
# TAX INVOICE
#
# “frveice No
#
# BEGIV-1030765
#
# Date
#
# :15/01/2019 11:05:16 AM
#
# Cashier
#
# : NG CHUAN MIN
#
# Sales Persor : FATIN
#
# Bill To
#
# : THE PEAK QUARRY WORKS
#
# Address
#
# .
#
# 1
#
# Prig
#
# Ar
#
# ~"n'Doo
#
# 000111
#
# 17193.00
#
# 193.00 SR
#
# KINGS SAFETY SHOES KWD BO5
#
# -
#
# Qty:
#
# Total
#
# xclude
#
# 133.00
#
# Total GST @6%:
#
# 0.00
#
# Total Inclusive GST:
#
# 193.00
#
# Round Amt:
#
# 2.00
#
# TOT
#
# 193.00
#
# 0000000004 318
#
# Approval Code:000
#
# 1)-c0
#
# Goods Scid Are Not Returnable & Refundable
#
# ++44Thank You. PIcasn_Cnme Again»++*
